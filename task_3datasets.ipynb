# %% [markdown]
# # First Dataset

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\rushi\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv('salary_data.csv')

# %%
#Accessing the rows and columns

# %%
df
# Out:
#             country_name continent_name wage_span  median_salary  \
# 0            Afghanistan           Asia   Monthly     853.740000
# 1          Aland Islands         Europe   Monthly    3319.240000
# 2                Albania         Europe   Monthly     832.840000
# 3                Algeria         Africa   Monthly    1148.840000
# 4         American Samoa        Oceania   Monthly    1390.000000
# ..                   ...            ...       ...            ...
# 216  Virgin Islands (US)  North America   Monthly    2380.000000
# 217       Western Sahara         Africa   Monthly     908.560000
# 218                Yemen           Asia   Monthly     120.980000
# 219               Zambia         Africa   Monthly       0.261335
# 220             Zimbabwe         Africa   Monthly     555.402040
#
#      average_salary  lowest_salary  highest_salary
# 0       1001.150000     252.530000     4460.970000
# 1       3858.350000     972.520000    17124.740000
# ...

# %%
df.head()
# Out:
#      country_name continent_name wage_span  median_salary  average_salary  \
# 0     Afghanistan           Asia   Monthly         853.74         1001.15
# 1   Aland Islands         Europe   Monthly        3319.24         3858.35
# 2         Albania         Europe   Monthly         832.84          956.92
# 3         Algeria         Africa   Monthly        1148.84         1308.81
# 4  American Samoa        Oceania   Monthly        1390.00         1570.00
#
#    lowest_salary  highest_salary
# 0         252.53         4460.97
# 1         972.52        17124.74
# 2         241.22         4258.49
# 3         330.11         5824.18
# 4         400.00         6980.00

# %%
df.tail()
# Out:
#             country_name continent_name wage_span  median_salary  \
# 216  Virgin Islands (US)  North America   Monthly    2380.000000
# 217       Western Sahara         Africa   Monthly     908.560000
# 218                Yemen           Asia   Monthly     120.980000
# 219               Zambia         Africa   Monthly       0.261335
# 220             Zimbabwe         Africa   Monthly     555.402040
#
#      average_salary  lowest_salary  highest_salary
# 216     2710.000000     680.000000    12000.000000
# 217     1011.670000     254.860000     4503.890000
# 218      133.360000      33.620000      594.930000
# 219        0.285524       0.072092        1.271103
# 220      602.376350     151.423050     2674.772000

# %%
df.head(20)
# Out:
#            country_name continent_name wage_span  median_salary  \
# 0           Afghanistan           Asia   Monthly         853.74
# 1         Aland Islands         Europe   Monthly        3319.24
# 2               Albania         Europe   Monthly         832.84
# 3               Algeria         Africa   Monthly        1148.84
# 4        American Samoa        Oceania   Monthly        1390.00
# 5               Andorra         Europe   Monthly        3668.08
# 6                Angola         Africa   Monthly         284.39
# 7   Antigua and Barbuda      Caribbean   Monthly        1548.15
# 8             Argentina  South America   Monthly         110.28
# 9               Armenia           Asia   Monthly        1700.25
# 10                Aruba      Caribbean   Monthly        1106.15
# 11            Australia        Oceania   Monthly        4306.45
# 12              Austria         Europe   Monthly        3572.94
# 13           Azerbaijan           Asia   Monthly        1558.82
# ...

# %%
df.tail(20)
# Out:
#                  country_name    continent_name wage_span  median_salary  \
# 201                   Tunisia            Africa   Monthly    1088.330000
# 202                    Turkey              Asia   Monthly     254.100000
# 203              Turkmenistan              Asia   Monthly    1342.860000
# 204  Turks and Caicos Islands     North America   Monthly    1350.000000
# 205                    Uganda            Africa   Monthly     645.210000
# 206                   Ukraine            Europe   Monthly     530.730000
# 207      United Arab Emirates              Asia   Monthly    3324.250000
# 208            United Kingdom            Europe   Monthly    6300.000000
# 209             United States  Northern America   Monthly    6966.000000
# 210                   Uruguay     South America   Monthly     773.640000
# 211                Uzbekistan              Asia   Monthly      97.250000
# 212                   Vanuatu           Oceania   Monthly     750.740000
# ...

# %%
df[40:50]
# Out:
#                  country_name   continent_name wage_span  median_salary  \
# 40                      Chile    South America   Monthly        1890.40
# 41                      China             Asia   Monthly        3684.93
# 42                   Colombia    South America   Monthly         995.60
# 43                    Comoros           Africa   Monthly         567.21
# 44                      Congo           Africa   Monthly        1058.67
# 45  Congo Democratic Republic           Africa   Monthly         170.39
# 46               Cook Islands          Oceania   Monthly        2538.92
# 47                 Costa Rica  Central America   Monthly        4016.06
# 48               Cote Divoire           Africa   Monthly         497.91
# 49                    Croatia           Europe   Monthly        1935.48
#
#     average_salary  lowest_salary  highest_salary
# 40         2090.56         525.98         9274.09
# 41         4027.40        1015.07        17945.21
# ...

# %%
df['country_name']
# Out:
# 0              Afghanistan
# 1            Aland Islands
# 2                  Albania
# 3                  Algeria
# 4           American Samoa
#               ...
# 216    Virgin Islands (US)
# 217         Western Sahara
# 218                  Yemen
# 219                 Zambia
# 220               Zimbabwe
# Name: country_name, Length: 221, dtype: object

# %%
df[['average_salary','continent_name','country_name']]
# Out:
#      average_salary continent_name         country_name
# 0       1001.150000           Asia          Afghanistan
# 1       3858.350000         Europe        Aland Islands
# 2        956.920000         Europe              Albania
# 3       1308.810000         Africa              Algeria
# 4       1570.000000        Oceania       American Samoa
# ..              ...            ...                  ...
# 216     2710.000000  North America  Virgin Islands (US)
# 217     1011.670000         Africa       Western Sahara
# 218      133.360000           Asia                Yemen
# 219        0.285524         Africa               Zambia
# 220      602.376350         Africa             Zimbabwe
#
# [221 rows x 3 columns]

# %%
df[10:20]['average_salary']
# Out:
# 10    1268.16
# 11    4903.23
# 12    4016.91
# 13    1741.18
# 14    3908.00
# 15    3936.17
# 16     236.71
# 17    1635.00
# 18     983.28
# 19    6522.20
# Name: average_salary, dtype: float64

# %%
list1=list(df['median_salary'])

# %%
for i in list1:
    if i >1500:
        print(i)
# Out:
# 3319.24
# 3668.08
# 1548.15
# 1700.25
# 4306.45
# 3572.94
# 1558.82
# 3541.0
# 3617.02
# 5729.39
# 1730.0
# 2360.0
# 2110.29
# 1605.41
# 6311.03
# 1706.29
# 3430.97
# 1890.4
# 3684.93
# 2538.92
# 4016.06
# 1935.48
# 1976.74
# 2310.03
# 5084.99
# 2030.0
# 2579.28
# 3484.42
# 1939.13
# 4238.9
# 3769.56
# 2896.41
# 2309.7
# 3731.5
# 3567.07
# 2241.01
# 3526.91
# 2066.67
# 3985.2
# 8689.02
# 4252.87
# 4661.2
# 3021.14
# 3467.23
# 3158.67
# 5817.07
# 1946.4
# 2206.45
# 2593.42
# 1654.0727
# 5224.04
# 4767.44
# 4439.75
# 2070.0
# 2949.26
# 2389.01
# 1681.97
# 4112.05
# 2621.56
# 1634.24
# 4756.87
# 2268.16
# 4196.41
# 1820.0
# 4420.02
# 3932.29
# 2380.0
# 1510.0
# 1890.0
# 1825.86
# 2537.0
# 3846.15
# 1966.17
# 1739.87
# 3086.68
# 4450.32
# 3840.0
# 5647.06
# 2114.16
# 1934.46
# 2579.28
# 3568.16
# 9836.07
# 3571.43
# 2432.28
# 3324.25
# 6300.0
# 6966.0
# 3282.02
# 1600.0
# 2380.0

# %%
#Use of loc and iloc

# %%
df.loc[10:20,['continent_name','average_salary','median_salary']]
# Out:
#      continent_name  average_salary  median_salary
# 10        Caribbean         1268.16        1106.15
# 11          Oceania         4903.23        4306.45
# 12           Europe         4016.91        3572.94
# 13             Asia         1741.18        1558.82
# 14    North America         3908.00        3541.00
# 15             Asia         3936.17        3617.02
# 16             Asia          236.71         218.57
# 17        Caribbean         1635.00        1395.00
# 18           Europe          983.28         849.50
# 19           Europe         6522.20        5729.39
# 20  Central America         1965.00        1730.00

# %%
df.iloc[10:20,3:6]
# Out:
#     median_salary  average_salary  lowest_salary
# 10        1106.15         1268.16         318.44
# 11        4306.45         4903.23        1236.13
# 12        3572.94         4016.91        1014.80
# 13        1558.82         1741.18         441.18
# 14        3541.00         3908.00         983.00
# 15        3617.02         3936.17         984.04
# 16         218.57          236.71          59.68
# 17        1395.00         1635.00         410.00
# 18         849.50          983.28         247.49
# 19        5729.39         6522.20        1997.89

# %%
#describing the dataset

# %%
df.columns
# Out:
# Index(['country_name', 'continent_name', 'wage_span', 'median_salary',
#        'average_salary', 'lowest_salary', 'highest_salary'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=221, step=1)

# %%
df.describe()
# Out:
#        median_salary  average_salary  lowest_salary  highest_salary
# count     221.000000      221.000000     221.000000      221.000000
# mean     1762.631906     1982.339812     502.783204     8802.165619
# std      1634.708716     1835.429193     470.073328     8140.210641
# min         0.261335        0.285524       0.072092        1.271103
# 25%       567.210000      651.000000     163.930000     2900.480000
# 50%      1227.460000     1344.230000     339.450000     5974.360000
# 75%      2389.010000     2740.000000     690.000000    12050.740000
# max      9836.070000    11292.900000    2850.270000    50363.930000

# %%
df.shape
# Out:
# (221, 7)

# %%
df.dtypes
# Out:
# country_name       object
# continent_name     object
# wage_span          object
# median_salary     float64
# average_salary    float64
# lowest_salary     float64
# highest_salary    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_name    221 non-null    object
#  1   continent_name  221 non-null    object
#  2   wage_span       221 non-null    object
#  3   median_salary   221 non-null    float64
#  4   average_salary  221 non-null    float64
#  5   lowest_salary   221 non-null    float64
#  6   highest_salary  221 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 12.2+ KB

# %%
#counting values

# %%
df.size
# Out:
# 1547

# %%
df['country_name'].value_counts()
# Out:
# country_name
# Afghanistan             1
# Pakistan                1
# Nepal                   1
# Netherlands             1
# Netherlands Antilles    1
#                        ..
# Greece                  1
# Greenland               1
# Grenada                 1
# Guadeloupe              1
# Zimbabwe                1
# Name: count, Length: 221, dtype: int64

# %%
df[['country_name','continent_name']].value_counts()
# Out:
# country_name          continent_name
# Afghanistan           Asia                1
# Pakistan              Asia                1
# Nepal                 Asia                1
# Netherlands           Europe              1
# Netherlands Antilles  North America       1
#                                          ..
# Greece                Europe              1
# Greenland             Northern America    1
# Grenada               Caribbean           1
# Guadeloupe            Caribbean           1
# Zimbabwe              Africa              1
# Name: count, Length: 221, dtype: int64

# %%
#working on unique and non unique values

# %%
df['continent_name'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Caribbean',
#        'South America', 'North America', 'Central America',
#        'Northern America'], dtype=object)

# %%
df['continent_name'].nunique()
# Out:
# 9

# %%
#performing operations that makes changes to the columns of dataset

# %%
df['my column'] = range(221)

# %%
df.drop('highest_salary', axis=1, inplace = True)

# %%
df.rename(columns={'continent_name': 'continent', 'median_salary': 'salary'}, inplace=True)

# %%
df
# Out:
#             country_name      continent wage_span       salary  \
# 0            Afghanistan           Asia   Monthly   853.740000
# 1          Aland Islands         Europe   Monthly  3319.240000
# 2                Albania         Europe   Monthly   832.840000
# 3                Algeria         Africa   Monthly  1148.840000
# 4         American Samoa        Oceania   Monthly  1390.000000
# ..                   ...            ...       ...          ...
# 216  Virgin Islands (US)  North America   Monthly  2380.000000
# 217       Western Sahara         Africa   Monthly   908.560000
# 218                Yemen           Asia   Monthly   120.980000
# 219               Zambia         Africa   Monthly     0.261335
# 220             Zimbabwe         Africa   Monthly   555.402040
#
#      average_salary  lowest_salary  my column
# 0       1001.150000     252.530000          0
# 1       3858.350000     972.520000          1
# 2        956.920000     241.220000          2
# ...

# %%
#handelling null values

# %%
df.isnull().sum()
# Out:
# country_name      0
# continent         0
# wage_span         0
# salary            0
# average_salary    0
# lowest_salary     0
# my column         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.fillna('ClassA',inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#finding the average of column salary using two different methods

# %%
#first method:

# %%
total =df['salary'].sum()

# %%
count= df['salary'].count()

# %%
avg = total/count

# %%
avg
# Out:
# np.float64(1762.6319056924888)

# %%
#second method

# %%
df['salary'].sum()/df['salary'].shape
# Out:
# array([1762.63190569])

# %%
#find the percentage of null values

# %%
nullper = (df.isnull().sum().sum()/df.size)*100

# %%
nullper
# Out:
# np.float64(0.0)

# %%
#map function: it is used to transform or modify the values in series(single column)

# %%
series1 = df['lowest_salary']

# %%
def myfun (hello):
    return hello + 5000

# %%
series1.map(myfun)
# Out:
# 0      5252.530000
# 1      5972.520000
# 2      5241.220000
# 3      5330.110000
# 4      5400.000000
#           ...
# 216    5680.000000
# 217    5254.860000
# 218    5033.620000
# 219    5000.072092
# 220    5151.423050
# Name: lowest_salary, Length: 221, dtype: float64

# %%
type(df['lowest_salary'])
# Out:
# pandas.core.series.Series

# %%
#using as type

# %%
df['lowest_salary']= df['lowest_salary'].astype(int)

# %%
df
# Out:
#             country_name      continent wage_span       salary  \
# 0            Afghanistan           Asia   Monthly   853.740000
# 1          Aland Islands         Europe   Monthly  3319.240000
# 2                Albania         Europe   Monthly   832.840000
# 3                Algeria         Africa   Monthly  1148.840000
# 4         American Samoa        Oceania   Monthly  1390.000000
# ..                   ...            ...       ...          ...
# 216  Virgin Islands (US)  North America   Monthly  2380.000000
# 217       Western Sahara         Africa   Monthly   908.560000
# 218                Yemen           Asia   Monthly   120.980000
# 219               Zambia         Africa   Monthly     0.261335
# 220             Zimbabwe         Africa   Monthly   555.402040
#
#      average_salary  lowest_salary  my column
# 0       1001.150000            252          0
# 1       3858.350000            972          1
# 2        956.920000            241          2
# ...

# %%
#String Transformations

# %%
df['wage_span'].str.lower()
# Out:
# 0      monthly
# 1      monthly
# 2      monthly
# 3      monthly
# 4      monthly
#         ...
# 216    monthly
# 217    monthly
# 218    monthly
# 219    monthly
# 220    monthly
# Name: wage_span, Length: 221, dtype: object

# %%
df['wage_span'].str.upper()
# Out:
# 0      MONTHLY
# 1      MONTHLY
# 2      MONTHLY
# 3      MONTHLY
# 4      MONTHLY
#         ...
# 216    MONTHLY
# 217    MONTHLY
# 218    MONTHLY
# 219    MONTHLY
# 220    MONTHLY
# Name: wage_span, Length: 221, dtype: object

# %%
df['wage_span'].str.replace('n','u')
# Out:
# 0      Mouthly
# 1      Mouthly
# 2      Mouthly
# 3      Mouthly
# 4      Mouthly
#         ...
# 216    Mouthly
# 217    Mouthly
# 218    Mouthly
# 219    Mouthly
# 220    Mouthly
# Name: wage_span, Length: 221, dtype: object

# %%
df['wage_span'].str.contains('ly')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 216    True
# 217    True
# 218    True
# 219    True
# 220    True
# Name: wage_span, Length: 221, dtype: bool

# %%
df['wage_span'].str.contains('ly').sum()
# Out:
# np.int64(221)

# %%
df.isnull().sum()
# Out:
# country_name      0
# continent         0
# wage_span         0
# salary            0
# average_salary    0
# lowest_salary     0
# my column         0
# dtype: int64

# %% [markdown]
# # second dataset

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\rushi\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df2 = pd.read_csv('zomato_dataset.csv')

# %%
#Accessing the rows and columns

# %%
df2
# Out:
#               Restaurant_Name  Dining_Rating  Delivery_Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df2.head(20)
# Out:
#    Restaurant_Name  Dining_Rating  Delivery_Rating  Dining Votes  \
# 0       Doner King            3.9              4.2            39
# 1       Doner King            3.9              4.2            39
# 2       Doner King            3.9              4.2            39
# 3       Doner King            3.9              4.2            39
# 4       Doner King            3.9              4.2            39
# 5       Doner King            3.9              4.2            39
# 6       Doner King            3.9              4.2            39
# 7       Doner King            3.9              4.2            39
# 8       Doner King            3.9              4.2            39
# 9       Doner King            3.9              4.2            39
# 10      Doner King            3.9              4.2            39
# 11      Doner King            3.9              4.2            39
# 12      Doner King            3.9              4.2            39
# ...

# %%
df2.tail(20)
# Out:
#               Restaurant_Name  Dining_Rating  Delivery_Rating  Dining Votes  \
# 123637  Ariena Boutique Hotel            3.9              4.2            13
# 123638  Ariena Boutique Hotel            3.9              4.2            13
# 123639  Ariena Boutique Hotel            3.9              4.2            13
# 123640  Ariena Boutique Hotel            3.9              4.2            13
# 123641  Ariena Boutique Hotel            3.9              4.2            13
# 123642  Ariena Boutique Hotel            3.9              4.2            13
# 123643  Ariena Boutique Hotel            3.9              4.2            13
# 123644  Ariena Boutique Hotel            3.9              4.2            13
# 123645  Ariena Boutique Hotel            3.9              4.2            13
# 123646  Ariena Boutique Hotel            3.9              4.2            13
# 123647  Ariena Boutique Hotel            3.9              4.2            13
# ...

# %%
df2[40:50]
# Out:
#    Restaurant_Name  Dining_Rating  Delivery_Rating  Dining Votes  \
# 40      Doner King            3.9              4.2            39
# 41      Doner King            3.9              4.2            39
# 42      Doner King            3.9              4.2            39
# 43      Doner King            3.9              4.2            39
# 44      Doner King            3.9              4.2            39
# 45      Doner King            3.9              4.2            39
# 46       Taco Bell            4.3              3.7           117
# 47       Taco Bell            4.3              3.7           117
# 48       Taco Bell            4.3              3.7           117
# 49       Taco Bell            4.3              3.7           117
#
#     Delivery_Votes   Cuisine               Place_Name        City  \
# 40               0  Fast Food                Malakpet   Hyderabad
# 41               0  Fast Food                Malakpet   Hyderabad
# ...

# %%
df2[['Restaurant_Name','Dining_Rating','Delivery_Rating']]
# Out:
#               Restaurant_Name  Dining_Rating  Delivery_Rating
# 0                  Doner King            3.9              4.2
# 1                  Doner King            3.9              4.2
# 2                  Doner King            3.9              4.2
# 3                  Doner King            3.9              4.2
# 4                  Doner King            3.9              4.2
# ...                       ...            ...              ...
# 123652  Ariena Boutique Hotel            3.9              4.2
# 123653  Ariena Boutique Hotel            3.9              4.2
# 123654  Ariena Boutique Hotel            3.9              4.2
# 123655  Ariena Boutique Hotel            3.9              4.2
# 123656  Ariena Boutique Hotel            3.9              4.2
#
# [123657 rows x 3 columns]

# %%
#Use of loc and iloc

# %%
df2.loc[10:20,['Item_Name','Place_Name','City']]
# Out:
#                               Item_Name Place_Name        City
# 10  Fish Platter [Boneless Indian Basa]   Malakpet   Hyderabad
# 11          Special Platter Kebab Combo   Malakpet   Hyderabad
# 12                          Doner Kebab   Malakpet   Hyderabad
# 13                     Chicken Shawarma   Malakpet   Hyderabad
# 14         French Fries + Coke [220 ml]   Malakpet   Hyderabad
# 15                  Platter Kebab Combo   Malakpet   Hyderabad
# 16          Special Platter Kebab Combo   Malakpet   Hyderabad
# 17             Special Kebab Wrap Combo   Malakpet   Hyderabad
# 18             Special Doner Wrap Combo   Malakpet   Hyderabad
# 19               Chicken Tandoori Salad   Malakpet   Hyderabad
# 20                    Chicken BBQ Salad   Malakpet   Hyderabad

# %%
df2.iloc[10:20,3:6]
# Out:
#     Dining Votes  Delivery_Votes   Cuisine
# 10            39               0  Fast Food
# 11            39               0  Fast Food
# 12            39               0  Fast Food
# 13            39               0  Fast Food
# 14            39               0  Fast Food
# 15            39               0  Fast Food
# 16            39               0  Fast Food
# 17            39               0  Fast Food
# 18            39               0  Fast Food
# 19            39               0  Fast Food

# %%
#describing the dataset

# %%
df2.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining Votes',
#        'Delivery_Votes', 'Cuisine ', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices'],
#       dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=123657, step=1)

# %%
df2.describe()
# Out:
#        Dining_Rating  Delivery_Rating   Dining Votes  Delivery_Votes  \
# count   91421.000000    122377.000000  123657.000000   123657.000000
# mean        3.822264         3.963184     152.729858      115.763725
# std         0.408693         0.245900     232.214061      243.970828
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.600000         3.800000       0.000000        0.000000
# 50%         3.900000         4.000000      30.000000        0.000000
# 75%         4.100000         4.100000     217.000000       23.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices
# count  123657.000000  123657.000000
# mean       24.666772     241.378399
# std       125.236009     192.830713
# min         0.000000       0.950000
# 25%         0.000000     130.000000
# 50%         0.000000     208.570000
# 75%        15.000000     299.000000
# max      9750.000000   12024.000000

# %%
df2.shape
# Out:
# (123657, 12)

# %%
df2.dtypes
# Out:
# Restaurant_Name     object
# Dining_Rating      float64
# Delivery_Rating    float64
# Dining Votes         int64
# Delivery_Votes       int64
# Cuisine             object
# Place_Name          object
# City                object
# Item_Name           object
# Best_Seller         object
# Votes                int64
# Prices             float64
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant_Name  123657 non-null  object
#  1   Dining_Rating    91421 non-null   float64
#  2   Delivery_Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery_Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place_Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item_Name        123657 non-null  object
#  9   Best_Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
#counting values

# %%
df2.size
# Out:
# 1483884

# %%
df2.value_counts()
# Out:
# Restaurant_Name         Dining_Rating  Delivery_Rating  Dining Votes  Delivery_Votes  Cuisine    Place_Name         City     Item_Name                          Best_Seller               Votes  Prices
# Cafe Durbar AFC         3.8            3.7              36            0               Beverages  Pallimukku         Kochi    AFC Royal Burger                   BESTSELLER                129    299.00    6
#                                                                                                                              Snack Box                          BESTSELLER                93     259.00    6
# Domino's Pizza          3.9            3.9              563           0               Fast Food  Entally            Kolkata  Pepper Barbecue Chicken Pizza      BESTSELLER                103    259.00    6
# ...

# %%
df2['Item_Name'].value_counts()
# Out:
# Item_Name
# Veg Fried Rice                   322
# Paneer Butter Masala             319
# Chicken Fried Rice               278
# Jeera Rice                       231
# Chicken Biryani                  226
#                                 ...
# Chicken Chinese Choupsey           1
# Chicken Burn Chilli Noodles        1
# Chicken Chilli Oyster Noodles      1
# Prawn American Choupsey            1
# ChickenTuktuk                      1
# Name: count, Length: 55693, dtype: int64

# %%
#working on unique and non unique values

# %%
df2['Restaurant_Name'].unique()
# Out:
# array(['Doner King', 'Taco Bell', 'BrownBear', 'Crystal Restaurant & Bar',
#        'Siddique Kabab Centre', 'Shah Ghouse Special Shawarma',
#        'Taj Mahal - Taj Mahal Hotel', 'Burger King', 'Papadams Blue',
#        'Ovenstory Pizza', 'Italian Pizzeria', 'Al Rabea Mandi House',
#        'Govind Dosa', 'Universal Al Mataam Mandi Kebab & Biryani',
#        'The Thickshake Factory', 'Platform 65', 'Food Track',
#        'The Burger Club', 'Acme Candy Food', 'MS Bakery & Sweets',
#        'New Grand Restaurant & Bakery', 'Al - Hamoor Arabian Restaurant',
#        "McDonald's", 'Capital Multi Cuisine Restaurant',
#        'Mayur Pan House', 'Yashwanth Pizza Den', 'Hotel Nayaab',
#        'Red Bucket Biryani', 'Hotel Shadab', 'Mughal Restaurant',
#        'UBQ by Barbeque Nation', 'Santosh Dhaba', 'Tipsy Topsy Bakery',
#        'Shah Ghouse Hotel & Restaurant', "La Pino'z Pizza", 'Istanbul',
#        'Iqbal Cafe', 'Barbeque Nation',
# ...

# %%
df2['Restaurant_Name'].nunique()
# Out:
# 826

# %%
#performing operations that makes changes to the columns of dataset

# %%
df2['new column'] = range(123657)

# %%
df2.drop('new column', axis=1, inplace = True)

# %%
df2.rename(columns={'Delivery_Votes':'d_votes','Delivery_Rating':'d_rating'},inplace=True)

# %%
#handelling null values

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(129231)

# %%
df2.dropna(inplace=True)

# %%
df2.fillna('Gurleen',inplace=True)

# %%
#finding avg of column Dining Votes

# %%
df2['Dining Votes'].sum()/df2['Dining Votes'].shape
# Out:
# array([207.7467372])

# %%
#finding the percentage of null values

# %%
nullper = (df2.isnull().sum().sum()/df2.size)*100

# %%
nullper
# Out:
# np.float64(0.0)

# %%
#map function: it is used to transform or modify the values in series(single column)

# %%
series1 = df2['Prices']

# %%
def myfun (hello):
    return hello + 5000

# %%
series1.map(myfun)
# Out:
# 0         5249.0
# 1         5129.0
# 3         5189.0
# 4         5205.0
# 5         5199.0
#            ...
# 123605    5325.0
# 123614    5255.0
# 123635    5195.0
# 123650    5525.0
# 123656    5595.0
# Name: Prices, Length: 20228, dtype: float64

# %%
#using as type

# %%
df2['Prices']= df2['Prices'].astype(int)

# %%
#String Transformations

# %%
df2['City'].str.lower()
# Out:
# 0          hyderabad
# 1          hyderabad
# 3          hyderabad
# 4          hyderabad
# 5          hyderabad
#              ...
# 123605        raipur
# 123614        raipur
# 123635        raipur
# 123650        raipur
# 123656        raipur
# Name: City, Length: 20228, dtype: object

# %%
df2['City'].str.upper()
# Out:
# 0          HYDERABAD
# 1          HYDERABAD
# 3          HYDERABAD
# 4          HYDERABAD
# 5          HYDERABAD
#              ...
# 123605        RAIPUR
# 123614        RAIPUR
# 123635        RAIPUR
# 123650        RAIPUR
# 123656        RAIPUR
# Name: City, Length: 20228, dtype: object

# %%
df2['City'].str.replace('e','a')
# Out:
# 0          Hydarabad
# 1          Hydarabad
# 3          Hydarabad
# 4          Hydarabad
# 5          Hydarabad
#              ...
# 123605        Raipur
# 123614        Raipur
# 123635        Raipur
# 123650        Raipur
# 123656        Raipur
# Name: City, Length: 20228, dtype: object

# %%
df2['City'].str.contains('d')
# Out:
# 0          True
# 1          True
# 3          True
# 4          True
# 5          True
#           ...
# 123605    False
# 123614    False
# 123635    False
# 123650    False
# 123656    False
# Name: City, Length: 20228, dtype: bool

# %%
df2['City'].str.contains('d').sum()
# Out:
# np.int64(4263)

# %% [markdown]
# # third dataset

# %%
df3 = pd.read_csv('matches.csv')

# %%
df3
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df3.rename(columns={'match_type':'type','venue':'place'},inplace=True)

# %%
df3.isnull().sum().sum()
# Out:
# np.int64(1160)

# %%
df3.dropna(inplace=True)

# %%
df3.fillna('Hii',inplace=True)

# %%
df3['result_margin'].sum()/df3['result_margin'].shape
# Out:
# array([13.23809524])

# %%
nullper = (df3.isnull().sum().sum()/df3.size)*100

# %%
nullper
# Out:
# np.float64(0.0)

# %%
series1 = df3['target_overs']

# %%
def myfun (idk):
    return idk + 7000

# %%
series1.map(myfun)
# Out:
# 38      7008.0
# 41      7008.0
# 60      7006.0
# 63      7009.2
# 89      7018.0
# 192     7017.0
# 221     7010.0
# 231     7013.0
# 429     7005.0
# 476     7012.0
# 508     7006.0
# 538     7011.0
# 561     7009.0
# 565     7011.0
# 566     7014.0
# 633     7006.0
# 641     7006.0
# 653     7013.0
# 667     7012.0
# 951     7016.0
# 1023    7015.0
# Name: target_overs, dtype: float64

# %%
df3['target_runs']= df3['target_runs'].astype(int)

# %%
df3['player_of_match'].str.lower()
# Out:
# 38      dpmd jayawardene
# 41               m ntini
# 60            dl vettori
# 63              ch gayle
# 89             ml hayden
# 192          bb mccullum
# 221        iqbal abdulla
# 231             ch gayle
# 429             dw steyn
# 476            da warner
# 508              v kohli
# 538             ab dinda
# 561            yk pathan
# 565             ab dinda
# 566              v kohli
# 633      nm coulter-nile
# 641            sv samson
# 653             kl rahul
# 667              rr pant
# 951       arshdeep singh
# 1023           dp conway
# Name: player_of_match, dtype: object

# %%
df3['player_of_match'].str.upper()
# Out:
# 38      DPMD JAYAWARDENE
# 41               M NTINI
# 60            DL VETTORI
# 63              CH GAYLE
# 89             ML HAYDEN
# 192          BB MCCULLUM
# 221        IQBAL ABDULLA
# 231             CH GAYLE
# 429             DW STEYN
# 476            DA WARNER
# 508              V KOHLI
# 538             AB DINDA
# 561            YK PATHAN
# 565             AB DINDA
# 566              V KOHLI
# 633      NM COULTER-NILE
# 641            SV SAMSON
# 653             KL RAHUL
# 667              RR PANT
# 951       ARSHDEEP SINGH
# 1023           DP CONWAY
# Name: player_of_match, dtype: object

# %%
df3['player_of_match'].str.replace('e','a')
# Out:
# 38      DPMD Jayawardana
# 41               M Ntini
# 60            DL Vattori
# 63              CH Gayla
# 89             ML Haydan
# 192          BB McCullum
# 221        Iqbal Abdulla
# 231             CH Gayla
# 429             DW Stayn
# 476            DA Warnar
# 508              V Kohli
# 538             AB Dinda
# 561            YK Pathan
# 565             AB Dinda
# 566              V Kohli
# 633      NM Coultar-Nila
# 641            SV Samson
# 653             KL Rahul
# 667              RR Pant
# 951       Arshdaap Singh
# 1023           DP Conway
# Name: player_of_match, dtype: object

# %%
df3['player_of_match'].str.contains('l')
# Out:
# 38      False
# 41      False
# 60      False
# 63       True
# 89      False
# 192      True
# 221      True
# 231      True
# 429     False
# 476     False
# 508      True
# 538     False
# 561     False
# 565     False
# 566      True
# 633      True
# 641     False
# 653      True
# 667     False
# 951     False
# 1023    False
# Name: player_of_match, dtype: bool

# %%
df3['player_of_match'].str.contains('l').sum()
# Out:
# np.int64(8)
